# %% [markdown]
# # Abismal GUI
#
# Graphical interface for [abismal](https://github.com/rs-station/abismal) serial
# diffraction merging. Run the cell below.
#
# **JupyterLab / HPC:** files are browsed server-side — navigate to your data with the
# file browser in the GUI.
# **Google Colab:** upload your files to the session (the Files pane in the left
# sidebar), then browse to `/content`. For something to try straight away, use
# `launch(example_data=True)` to fetch a lysozyme dataset.

# %%
# %pip install -q "abismal[gui] @ git+https://github.com/rs-station/abismal@656ea83d01a81998defe381311c54ac6ea13236b"

from abismal.gui import launch

launch(example_data=True, branch='colab-debug')

# %%
# Diagnostics -- added by devtools/colab_deploy.py, not in the committed notebook.
# Run this and paste the output back. It reports the environment as JSON: which
# packages the install actually changed, where the file pickers resolve to, and
# whether TensorFlow was already loaded when the install ran.
import json, urllib.request

_src = urllib.request.urlopen("https://raw.githubusercontent.com/rs-station/abismal/656ea83d01a81998defe381311c54ac6ea13236b/devtools/collect_colab_debug.py").read()
_ns = {}
exec(_src, _ns)
print(json.dumps(_ns["probe"](), indent=2, sort_keys=True, default=str))
